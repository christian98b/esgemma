# %%
from eval_function import evaluate_llm_output, print_results


ground_truth = [
    ("Carbon neutral(ity)", "2040", "Thus Our company aims to achieve carbon neutrality by 2040. This ambitious goal reflects our commitment to sustainability and reducing our environmental impact."),
    ("Carbon neutral(ity)", "2030", "We have set a target to reach carbon neutrality by 2030. This demonstrates our dedication to addressing climate change and leading in sustainable business practices."),
    ("Carbon neutral(ity)", "2050", "The organization's long-term plan includes achieving carbon neutrality by 2050. This aligns with global efforts to mitigate climate change and transition to a low-carbon economy."),
    ("Carbon neutral(ity)", "2035", "Our carbon neutrality target is set for 2035. This mid-term goal balances ambition with practicality in our sustainability journey."),
    ("Carbon neutral(ity)", "2050", "We are committed to becoming carbon neutral by 2050. This target is part of our comprehensive strategy to reduce greenhouse gas emissions and promote sustainable operations."),
    ("Carbon neutral(ity)", "2030", "The company has announced its intention to achieve carbon neutrality by 2030. This accelerated timeline showcases our urgency in addressing climate-related challenges."),
    ("Carbon neutral(ity)", "2040", "Our carbon neutrality goal is set for 2040. This target allows us to make significant progress while ensuring a realistic and achievable transition."),
    ("Carbon neutral(ity)", "2020", "We proudly announced achieving carbon neutrality in 2020. This accomplishment marks a significant milestone in our sustainability efforts and sets a precedent for future environmental initiatives."),
    ("Carbon neutral(ity)", "2035", "The organization aims to reach carbon neutrality by 2035. This target reflects our balanced approach to sustainability, combining ambition with feasibility."),
    ("Carbon neutral(ity)", "2050", "Our long-term sustainability plan includes achieving carbon neutrality by 2050. This aligns with global climate goals and demonstrates our commitment to a sustainable future."),
    ("Emissions reduction target", "2035", "We have set an emissions reduction target to be achieved by 2035. This goal is a crucial part of our strategy to minimize our environmental footprint and contribute to global climate action."),
    ("Emissions reduction target", "2030", "Our emissions reduction target is set for 2030. This ambitious goal underscores our commitment to rapid decarbonization and environmental stewardship."),
    ("Emissions reduction target", "2030", "The company has established an emissions reduction target to be met by 2030. This target is a key component of our sustainability strategy and aligns with science-based climate objectives."),
    ("Emissions reduction target", "2030", "We aim to significantly reduce our emissions by 2030. This target reflects our proactive approach to addressing climate change and reducing our environmental impact."),
    ("Emissions reduction target", "2030", "Our emissions reduction target for 2030 demonstrates our commitment to sustainable operations. This goal is integral to our broader environmental strategy and corporate responsibility."),
    ("Emissions reduction target", "2035", "The organization has set an emissions reduction target for 2035. This mid-term goal allows us to make substantial progress while ensuring a feasible and well-planned transition."),
    ("Emissions reduction target", "2025", "We have an ambitious emissions reduction target set for 2025. This near-term goal showcases our urgency in addressing climate change and our commitment to immediate action."),
    ("Emissions reduction target", "2025", "Our emissions reduction target for 2025 reflects our commitment to rapid and meaningful change. This short-term goal emphasizes the immediacy of our climate action plans."),
    ("Emissions reduction target", "2030", "The company's emissions reduction target is set for 2030. This aligns with global climate goals and demonstrates our dedication to sustainable business practices."),
    ("Carbon neutral(ity)", "2050", "We are working towards carbon neutrality by 2050. This long-term commitment is part of our comprehensive strategy to address climate change and promote sustainability."),
    ("Net zero", "2050", "Our company has set a net zero target for 2050. This ambitious goal demonstrates our long-term commitment to eliminating our carbon footprint and contributing to global climate solutions."),
    ("Net zero", "2040", "We aim to achieve net zero emissions by 2040. This accelerated timeline reflects our strong commitment to climate action and sustainable business practices."),
    ("Net zero", "2050", "The organization has committed to reaching net zero emissions by 2050. This target aligns with global efforts to limit climate change and transition to a low-carbon economy."),
    ("Net zero", "2050", "Our net zero target is set for 2050. This long-term goal is a cornerstone of our sustainability strategy and demonstrates our commitment to environmental stewardship."),
    ("Net zero", "2040", "We have set an ambitious net zero target for 2040. This goal underscores our dedication to rapid decarbonization and leadership in sustainable business practices."),
    ("Net zero", "2040", "The company aims to achieve net zero emissions by 2040. This target reflects our proactive approach to addressing climate change and our commitment to sustainable operations."),
    ("Net zero", "2050", "Our net zero emissions target is set for 2050. This aligns with global climate objectives and showcases our long-term commitment to environmental sustainability."),
    ("Net zero", "2030", "We have announced an ambitious net zero target for 2030. This accelerated timeline demonstrates our urgency in addressing climate change and our commitment to immediate, impactful action."),
    ("Net zero", "2050", "The organization is committed to achieving net zero emissions by 2050. This target is a key part of our long-term sustainability strategy and our contribution to global climate efforts."),
    ("Net zero", "2050", "Our net zero goal is set for 2050. This long-term target allows us to plan and implement comprehensive changes across our operations to eliminate our carbon footprint."),
    ("No target", "No target", "Currently, our company has not set a specific emissions reduction or carbon neutrality target. We are in the process of evaluating our environmental impact and considering potential sustainability goals for the future."),
    ("No target", "No target", "At this time, we have not established a formal emissions reduction or carbon neutrality target. We are actively assessing our environmental footprint and exploring potential sustainability initiatives."),
    ("No target", "No target", "The organization has not yet defined a specific emissions reduction or carbon neutrality target. We are carefully analyzing our operations and industry best practices to inform our future sustainability strategy."),
    ("No target", "No target", "We have not set a formal emissions reduction or carbon neutrality target at this point. Our focus is on gathering comprehensive data on our environmental impact to inform future sustainability decisions."),
    ("No target", "No target", "Currently, there is no specific emissions reduction or carbon neutrality target in place for our company. We are in the early stages of developing our sustainability strategy and evaluating potential goals."),
    ("No target", "No target", "Our organization has not yet established an emissions reduction or carbon neutrality target. We are committed to sustainability and are in the process of assessing various options for future environmental goals."),
    ("No target", "No target", "At present, we do not have a defined emissions reduction or carbon neutrality target. We are actively engaging with stakeholders and industry experts to shape our approach to sustainability."),
    ("No target", "No target", "The company has not set a specific emissions reduction or carbon neutrality target at this time. We are conducting a thorough analysis of our environmental impact to inform our future sustainability strategy."),
    ("No target", "No target", "We have not yet announced an emissions reduction or carbon neutrality target. Our team is carefully evaluating our operations and industry trends to develop meaningful and achievable sustainability goals."),
    ("No target", "No target", "Currently, there is no formal emissions reduction or carbon neutrality target in place. We are committed to environmental responsibility and are in the process of defining our long-term sustainability objectives.")
]

llm_output = [
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2040</end_target_year><quote>Our company aims to achieve carbon neutrality by 2040.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2030</end_target_year><quote>We have set a target to reach carbon neutrality by 2030.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2050</end_target_year><quote>The organization\'s long-term plan includes achieving carbon neutrality by 2050.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2035</end_target_year><quote>Our carbon neutrality target is set for 2035.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2050</end_target_year><quote>We are committed to becoming carbon neutral by 2050.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2030</end_target_year><quote>The company has announced its intention to achieve carbon neutrality by 2030.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2040</end_target_year><quote>Our carbon neutrality goal is set for 2040.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2020</end_target_year><quote>We proudly announced achieving carbon neutrality in 2020.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2035</end_target_year><quote>The organization aims to reach carbon neutrality by 2035.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2050</end_target_year><quote>Our long-term sustainability plan includes achieving carbon neutrality by 2050.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2035</end_target_year><quote>We have set an emissions reduction target to be achieved by 2035.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2030</end_target_year><quote>Our emissions reduction target is set for 2030.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2030</end_target_year><quote>The company has established an emissions reduction target to be met by 2030.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2030</end_target_year><quote>We aim to significantly reduce our emissions by 2030.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2030</end_target_year><quote>Our emissions reduction target for 2030 demonstrates our commitment to sustainable operations.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2035</end_target_year><quote>The organization has set an emissions reduction target for 2035.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2025</end_target_year><quote>We have an ambitious emissions reduction target set for 2025.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2025</end_target_year><quote>Our emissions reduction target for 2025 reflects our commitment to rapid and meaningful change.</quote><eos>',
    '<end_target>Emissions reduction target</end_target><end_target_year>2030</end_target_year><quote>The company\'s emissions reduction target is set for 2030.</quote><eos>',
    '<end_target>Carbon neutral(ity)</end_target><end_target_year>2050</end_target_year><quote>We are working towards carbon neutrality by 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>Our company has set a net zero target for 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2040</end_target_year><quote>We aim to achieve net zero emissions by 2040.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>The organization has committed to reaching net zero emissions by 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>Our net zero target is set for 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2040</end_target_year><quote>We have set an ambitious net zero target for 2040.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2040</end_target_year><quote>The company aims to achieve net zero emissions by 2040.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>Our net zero emissions target is set for 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2030</end_target_year><quote>We have announced an ambitious net zero target for 2030.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>The organization is committed to achieving net zero emissions by 2050.</quote><eos>',
    '<end_target>Net zero</end_target><end_target_year>2050</end_target_year><quote>Our net zero goal is set for 2050.</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>',
    '<end_target>No target</end_target><end_target_year>No target</end_target_year><quote>None</quote><eos>']

results = evaluate_llm_output(ground_truth, llm_output)
print_results(results)
# Out:
# Target Metrics:
# Overall - Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Class-specific metrics:
#   Carbon neutral(ity) - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   Emissions reduction target - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   Net zero - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   No target - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Year Metrics:
# Overall - Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Class-specific metrics:
#   2020 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   2025 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   2030 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   2035 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   2040 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   2050 - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
#   No target - Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# Quote Accuracy: 1.0000
#
# Overall Accuracy: 1.0000
# ...
